# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix

import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression, Ridge 
from sklearn.metrics import log_loss  
from sklearn.impute import SimpleImputer, KNNImputer

# %%
df_original=pd.read_csv("C:/Users/Sumit's/OneDrive/Desktop/M.L_01/venv/cibil_nn.csv")

# %%
df_processed=pd.read_csv(r"C:\Users\Sumit's\OneDrive\Desktop\M.L_01\venv\cibil_nn.csv")

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["AGE"], bins=20)
plt.title("AGE Distribution")
plt.show()

# %% [markdown]
# ### Pair Plot Observation
#
# The pair plot shows the relationship among the important features.
#
# - Some feature pairs show a positive trend.
# - A few features have weak relationships.
# - Some outliers are clearly visible.
# - Pair plots reveal patterns that cannot be observed from a single correlation value.

# %%
cols = [
    "Credit_Score",
    "AGE",
    "NETMONTHLYINCOME",
    "CC_utilization",
    "Time_With_Curr_Empr"
]

sns.pairplot(df[cols])
